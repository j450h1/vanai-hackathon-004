# %% [markdown]
# ### Load data into Google BigQuery to allow for SQL querying

# %%
from dotenv import load_dotenv
load_dotenv()

# Get project ID from .env
PROJECT_ID = os.getenv("PROJECT_ID")
DATASET_NAME = "vanai_hackathons"
TABLE_NAME = "music_survey_data"

INPUT_CSV_FILE_PATH=f"../data/raw/{TABLE_NAME}.csv"
OUTPUT_JSON_SCHEMA_FILE_PATH=f"../data/{TABLE_NAME}_schema_for_bq.json"

# %% [markdown]
# * Test the connection to bq using the command line tool

# %%
# !bq ls --project_id=bigquery-public-data worldpop
# Out:
#         tableId         Type    Labels       Time Partitioning               Clustered Fields
#  --------------------- ------- -------- --------------------------- ----------------------------------
#   population_grid_1km   TABLE            DAY (field: last_updated)   geog, country_name, alpha_3_code

# %%
# !bq mk --dataset \
  --project_id=$PROJECT_ID \
  $PROJECT_ID:$DATASET_NAME
# Out:
# Dataset 'jas-test:vanai_hackathons' successfully created.

# %%
# !pwd
# Out:
# /Users/jas/github/vanai-hackathon-004/scripts

# %%
# !echo $PROJECT_ID:$DATASET_NAME.$TABLE_NAME
# Out:
# jas-test:.

# %%
# !echo $DATASET_NAME
# Out:
# vanai_hackathons

# %%
# !echo $TABLE_NAME
# Out:
# music_survey_data

# %%
# !echo $PROJECT_ID:$DATASET_NAME
# Out:
# jas-test:vanai_hackathons

# %%
# !echo $PROJECT_ID:$DATASET_NAME.$TABLE_NAME
# Out:
# jas-test:.

# %%
# !echo "${PROJECT_ID}:${DATASET_NAME}.${TABLE_NAME}"
# Out:
# -test:.

# %%
# !echo $PROJECT_ID:$DATASET_NAME"."$TABLE_NAME
# Out:
# jas-test:vanai_hackathons.music_survey_data

# %%
# # Step 1: Load the CSV file into BigQuery and create a new table
# # The --autodetect flag tells BigQuery to automatically determine the schema
# # The --source_format=CSV specifies that the input is a CSV file
# !bq load \
#   --autodetect \
#   --source_format=CSV \
#   $PROJECT_ID:$DATASET_NAME"."$TABLE_NAME \
#   ../data/raw/$TABLE_NAME"."csv

# # Step 2: Verify the table creation and schema
# # This command will show the table details, including the automatically detected schema
# !bq show $PROJECT_ID:$DATASET_NAME"."$TABLE_NAME
# Out:
# Upload complete.
# Waiting on bqjob_r376f6247d61cb246_000001997a2f5e14_1 ... (0s) Current status: DONE
# BigQuery error in load operation: Error processing job 'jas-
# test:bqjob_r376f6247d61cb246_000001997a2f5e14_1': Error while reading data,
# error message: CSV table encountered too many errors, giving up. Rows: 429;
# errors: 100. Please look into the errors[] collection for more details.
# Failure details:
# - Error while reading data, error message: CSV processing encountered
# too many errors, giving up. Rows: 429; errors: 100; max bad: 0;
# error percent: 0
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 2 byte_offset_to_start_of_line: 2043
# column_index: 57 column_name: "Q19_Lyric_that_st..." column_type:
# STRING value: "Clarify, rather t..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 25 byte_offset_to_start_of_line: 29065
# column_index: 54 column_name: "Q18_Life_theme_song" column_type:
# STRING value: "I\342\200\231m still stand..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 26 byte_offset_to_start_of_line: 29933
# column_index: 3 column_name: "engagement_id" column_type: STRING
# value: "Your song "
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 35 byte_offset_to_start_of_line: 38592
# column_index: 57 column_name: "Q19_Lyric_that_st..." column_type:
# STRING value: "This is for every..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 38 byte_offset_to_start_of_line: 41324
# column_index: 10 column_name: "Q3_artist_that_pu..." column_type:
# STRING value: "Merle haggard "
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 53 byte_offset_to_start_of_line: 53330
# column_index: 10 column_name: "Q3_artist_that_pu..." column_type:
# STRING value: "Dinah Washington,..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 62 byte_offset_to_start_of_line: 60589
# column_index: 10 column_name: "Q3_artist_that_pu..." column_type:
# STRING value: "elvis"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 69 byte_offset_to_start_of_line: 65557
# column_index: 57 column_name: "Q19_Lyric_that_st..." column_type:
# STRING value: "I didn\342\200\231t have i..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 79 byte_offset_to_start_of_line: 73099
# column_index: 10 column_name: "Q3_artist_that_pu..." column_type:
# STRING value: "James Brown"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 87 byte_offset_to_start_of_line: 79825
# column_index: 57 column_name: "Q19_Lyric_that_st..." column_type:
# STRING value: "The church bell c..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 101 byte_offset_to_start_of_line:
# 94938 column_index: 54 column_name: "Q18_Life_theme_song"
# column_type: STRING value: "danny boy-pride i..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 105 byte_offset_to_start_of_line:
# 97081 column_index: 14 column_name: "Q5_Music_formal_c..."
# column_type: STRING value: "never listened much"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 110 byte_offset_to_start_of_line:
# 101916 column_index: 54 column_name: "Q18_Life_theme_song"
# column_type: STRING value: "Making memmories ..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 129 byte_offset_to_start_of_line:
# 123648 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "You Raise Me Up"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 133 byte_offset_to_start_of_line:
# 125910 column_index: 54 column_name: "Q18_Life_theme_song"
# column_type: STRING value: "Ghost Ship of Can..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 154 byte_offset_to_start_of_line:
# 150268 column_index: 54 column_name: "Q18_Life_theme_song"
# column_type: STRING value: "All by myself - C..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 167 byte_offset_to_start_of_line:
# 163327 column_index: 10 column_name: "Q3_artist_that_pu..."
# column_type: STRING value: "Bruce Springsteen"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 172 byte_offset_to_start_of_line:
# 167065 column_index: 14 column_name: "Q5_Music_formal_c..."
# column_type: STRING value: "learning how to r..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 178 byte_offset_to_start_of_line:
# 171744 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "no idea"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 181 byte_offset_to_start_of_line:
# 173849 column_index: 14 column_name: "Q5_Music_formal_c..."
# column_type: STRING value: "no more recording..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 220 byte_offset_to_start_of_line:
# 218646 column_index: 50 column_name: "Q16_Music_guilty_..."
# column_type: STRING value: "Words with meaning"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 221 byte_offset_to_start_of_line:
# 219481 column_index: 0 column_name: "participant_id" column_type:
# STRING value: ",NEUTRAL,0.637466..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 226 byte_offset_to_start_of_line:
# 224782 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "\"Start thinking \'..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 252 byte_offset_to_start_of_line:
# 255053 column_index: 10 column_name: "Q3_artist_that_pu..."
# column_type: STRING value: "Britney Spears"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 278 byte_offset_to_start_of_line:
# 286062 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "And I tell someon..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 282 byte_offset_to_start_of_line:
# 287861 column_index: 10 column_name: "Q3_artist_that_pu..."
# column_type: STRING value: "Queen"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 284 byte_offset_to_start_of_line:
# 289187 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "I can\342\200\231t pick ju..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 301 byte_offset_to_start_of_line:
# 306269 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "So pardon me whil..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 313 byte_offset_to_start_of_line:
# 317489 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "\"Southern trees b..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 330 byte_offset_to_start_of_line:
# 333031 column_index: 54 column_name: "Q18_Life_theme_song"
# column_type: STRING value: "\"Forever Young\"."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 333 byte_offset_to_start_of_line:
# 335346 column_index: 14 column_name: "Q5_Music_formal_c..."
# column_type: STRING value: "The variety "
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 348 byte_offset_to_start_of_line:
# 352012 column_index: 10 column_name: "Q3_artist_that_pu..."
# column_type: STRING value: "The Cure"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 360 byte_offset_to_start_of_line:
# 363028 column_index: 14 column_name: "Q5_Music_formal_c..."
# column_type: STRING value: "my music became m..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 362 byte_offset_to_start_of_line:
# 364567 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "Sounds of silence..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 367 byte_offset_to_start_of_line:
# 368689 column_index: 54 column_name: "Q18_Life_theme_song"
# column_type: STRING value: "Don\342\200\231t worry, be..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 370 byte_offset_to_start_of_line:
# 370961 column_index: 50 column_name: "Q16_Music_guilty_..."
# column_type: STRING value: "Idk what to say t..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 373 byte_offset_to_start_of_line:
# 372063 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "YOU BRUSHED MY EY..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 385 byte_offset_to_start_of_line:
# 385505 column_index: 10 column_name: "Q3_artist_that_pu..."
# column_type: STRING value: "the Doors"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 392 byte_offset_to_start_of_line:
# 391192 column_index: 14 column_name: "Q5_Music_formal_c..."
# column_type: STRING value: "Had it in the car"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 394 byte_offset_to_start_of_line:
# 392297 column_index: 14 column_name: "Q5_Music_formal_c..."
# column_type: STRING value: "I remember gettin..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 407 byte_offset_to_start_of_line:
# 405335 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "Who Wants to Live..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 409 byte_offset_to_start_of_line:
# 406405 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "Because everythin..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 435 byte_offset_to_start_of_line:
# 433164 column_index: 54 column_name: "Q18_Life_theme_song"
# column_type: STRING value: "The hand that fee..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 448 byte_offset_to_start_of_line:
# 446731 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "take it now or le..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 462 byte_offset_to_start_of_line:
# 458273 column_index: 54 column_name: "Q18_Life_theme_song"
# column_type: STRING value: "No idea "
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 464 byte_offset_to_start_of_line:
# 459363 column_index: 54 column_name: "Q18_Life_theme_song"
# column_type: STRING value: "Wind beneath my w..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 488 byte_offset_to_start_of_line:
# 484328 column_index: 54 column_name: "Q18_Life_theme_song"
# column_type: STRING value: "Short story - bon..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 501 byte_offset_to_start_of_line:
# 498940 column_index: 14 column_name: "Q5_Music_formal_c..."
# column_type: STRING value: "increased sound q..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 509 byte_offset_to_start_of_line:
# 505880 column_index: 10 column_name: "Q3_artist_that_pu..."
# column_type: STRING value: "smoke on the water"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 517 byte_offset_to_start_of_line:
# 513465 column_index: 14 column_name: "Q5_Music_formal_c..."
# column_type: STRING value: "S"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 520 byte_offset_to_start_of_line:
# 515955 column_index: 57 column_name: "Q19_Lyric_that_st..."
# column_type: STRING value: "Afternoon Delight"
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 528 byte_offset_to_start_of_line:
# 519454 column_index: 14 column_name: "Q5_Music_formal_c..."
# column_type: STRING value: "Taps would get da..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 529 byte_offset_to_start_of_line:
# 519907 column_index: 40 column_name: "Q12_Music_bingo_7"
# column_type: STRING value: "Deutschland by Ra..."
# - Error while reading data, error message: Missing close quote
# character (").; line_number: 530 byte_offset_to_start_of_line:
# 520603 column_index: 4 column_name: "engagement_starte..."
# column_type: STRING value: "It\'s from Links 2..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 43
# byte_offset_to_start_of_line: 41552 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEGATIVE,0.47962..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 54
# byte_offset_to_start_of_line: 53580 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.982133..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 55
# byte_offset_to_start_of_line: 53659 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",POSITIVE,0.68918..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 56
# byte_offset_to_start_of_line: 54127 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.686199..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 63
# byte_offset_to_start_of_line: 60804 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.999325..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 64
# byte_offset_to_start_of_line: 60868 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.804458..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 65
# byte_offset_to_start_of_line: 61320 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.545476..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 73
# byte_offset_to_start_of_line: 66724 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEGATIVE,0.97159..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 80
# byte_offset_to_start_of_line: 73320 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.999688..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 81
# byte_offset_to_start_of_line: 73892 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEGATIVE,0.43853..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 102
# byte_offset_to_start_of_line: 95727 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.607101..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 103
# byte_offset_to_start_of_line: 95761 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.978813..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 106
# byte_offset_to_start_of_line: 97382 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEGATIVE,0.75721..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 168
# byte_offset_to_start_of_line: 163560 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.998984..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 169
# byte_offset_to_start_of_line: 164386 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.535956..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 173
# byte_offset_to_start_of_line: 167364 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.797337..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 174
# byte_offset_to_start_of_line: 167913 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEGATIVE,0.91837..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 179
# byte_offset_to_start_of_line: 172602 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.737002..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 182
# byte_offset_to_start_of_line: 174158 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEGATIVE,0.58340..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 183
# byte_offset_to_start_of_line: 174770 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.877760..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 253
# byte_offset_to_start_of_line: 255267 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.995567..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 283
# byte_offset_to_start_of_line: 288066 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.999660..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 334
# byte_offset_to_start_of_line: 335620 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.694747..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 335
# byte_offset_to_start_of_line: 336263 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",POSITIVE,0.91662..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 349
# byte_offset_to_start_of_line: 352233 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.940999..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 350
# byte_offset_to_start_of_line: 352361 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",MIXED,0.99920684..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 351
# byte_offset_to_start_of_line: 352803 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.923198..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 361
# byte_offset_to_start_of_line: 363481 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEGATIVE,0.70303..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 371
# byte_offset_to_start_of_line: 371780 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.486441..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 372
# byte_offset_to_start_of_line: 371809 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.934600..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 374
# byte_offset_to_start_of_line: 372890 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEGATIVE,0.76478..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 386
# byte_offset_to_start_of_line: 385732 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.998272..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 387
# byte_offset_to_start_of_line: 385819 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEGATIVE,0.49049..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 393
# byte_offset_to_start_of_line: 391472 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.952952..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 395
# byte_offset_to_start_of_line: 392824 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",POSITIVE,0.88607..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 396
# byte_offset_to_start_of_line: 393889 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",MIXED,0.5819885135,"
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 397
# byte_offset_to_start_of_line: 394211 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",MIXED,0.86172050..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 408
# byte_offset_to_start_of_line: 406140 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.638474..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 463
# byte_offset_to_start_of_line: 459074 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.703234..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 467
# byte_offset_to_start_of_line: 460127 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",POSITIVE,0.99036..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 489
# byte_offset_to_start_of_line: 485261 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",POSITIVE,0.52335..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 502
# byte_offset_to_start_of_line: 499214 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",POSITIVE,0.97301..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 503
# byte_offset_to_start_of_line: 499818 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",POSITIVE,0.95985..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 510
# byte_offset_to_start_of_line: 506113 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.592710..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 511
# byte_offset_to_start_of_line: 506166 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",NEUTRAL,0.997583..."
# - Error while reading data, error message: Data between close quote
# character (") and field separator.; line_number: 525
# byte_offset_to_start_of_line: 516900 column_index: 0 column_name:
# "participant_id" column_type: STRING value: ",POSITIVE,0.78322..."
# BigQuery error in show operation: Not found: Table jas-
# test:vanai_hackathons.music_survey_data

# %% [markdown]
# * Automatic schema detection didn't work

# %% [markdown]
# 1. **Prepare the Schema**: Since we want all columns to be strings, we can use a wildcard schema definition.
#
# 2. **Use the `bq load` Command**: We'll use the `bq load` command with appropriate flags to specify the source file, destination table, and schema.

# %%
# !bq load --source_format=CSV \
        --autodetect=false \
        --skip_leading_rows=1 \
        --max_bad_records=0 \
        --field_delimiter=',' \
        --quote="" \
        --schema='*' \
        $PROJECT_ID:$DATASET_NAME"."$TABLE_NAME \
        ../data/raw/$TABLE_NAME"."csv

# !bq show $PROJECT_ID:$DATASET_NAME"."$TABLE_NAME
# Out:
# BigQuery error in load operation: Invalid field name "*". Fields must contain
# the allowed characters, and be at most 300 characters long. For allowed
# characters, please refer to
# https://cloud.google.com/bigquery/docs/schemas#column_names
# BigQuery error in show operation: Not found: Table jas-
# test:vanai_hackathons.music_survey_data

# %%
import os
print(os.getcwd())
# Out:
# /Users/jas/github/vanai-hackathon-004/scripts

# %% [markdown]
# * Create custom code to create a json schema based on the data before uploading to BQ

# %%
import csv
import json
import re

def clean_column_name(name):
    # Replace invalid characters with underscore, start with letter or underscore, max 128 chars
    clean_name = re.sub(r'[^a-zA-Z0-9_]', '_', name)
    if not re.match(r'^[a-zA-Z_]', clean_name):
        clean_name = '_' + clean_name
    return clean_name[:128]

def generate_schema_from_csv(csv_path, json_path):
    with open(csv_path, 'r', newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        columns = next(reader)  # first row - column names

    schema = []
    for col in columns:
        clean_col = clean_column_name(col)
        schema.append({"name": clean_col, "type": "STRING"})

    with open(json_path, 'w', encoding='utf-8') as f:
        json.dump(schema, f, indent=2)

    print(f"Schema JSON saved to {json_path}")

# Example usage:
csv_file_path = INPUT_CSV_FILE_PATH      # change to your csv file path
json_schema_path = OUTPUT_JSON_SCHEMA_FILE_PATH # change to save location for schema json

generate_schema_from_csv(csv_file_path, json_schema_path)
# Out:
# Schema JSON saved to ../data/music_survey_data_schema_for_bq.json

# %%
# !bq load --source_format=CSV \
    --skip_leading_rows=1 \
    --schema=$OUTPUT_JSON_SCHEMA_FILE_PATH \
    $PROJECT_ID:$DATASET_NAME"."$TABLE_NAME \
    $INPUT_CSV_FILE_PATH

# !bq show $PROJECT_ID:$DATASET_NAME"."$TABLE_NAME
# Out:
# Upload complete.
# Waiting on bqjob_r3ff8724fe45041a8_000001997a43e6bc_1 ... (0s) Current status: DONE
# BigQuery error in load operation: Error processing job 'jas-
# test:bqjob_r3ff8724fe45041a8_000001997a43e6bc_1': Error while reading data,
# error message: CSV table encountered too many errors, giving up. Rows: 262;
# errors: 100. Please look into the errors[] collection for more details.
# Failure details:
# - Error while reading data, error message: CSV processing encountered
# too many errors, giving up. Rows: 262; errors: 100; max bad: 0;
# error percent: 0
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 2 byte_offset_to_start_of_line: 2043 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 35 byte_offset_to_start_of_line: 38592 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 69 byte_offset_to_start_of_line: 65557 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 87 byte_offset_to_start_of_line: 79825 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 129 byte_offset_to_start_of_line: 123648 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 178 byte_offset_to_start_of_line: 171744 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 226 byte_offset_to_start_of_line: 224782 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 278 byte_offset_to_start_of_line: 286062 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 284 byte_offset_to_start_of_line: 289187 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 301 byte_offset_to_start_of_line: 306269 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 313 byte_offset_to_start_of_line: 317489 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 58 columns.;
# line_number: 362 byte_offset_to_start_of_line: 364567 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 29 columns.;
# line_number: 3 byte_offset_to_start_of_line: 3086 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 29 columns.;
# line_number: 27 byte_offset_to_start_of_line: 29990 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 29 columns.;
# line_number: 36 byte_offset_to_start_of_line: 39779 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 29 columns.;
# line_number: 89 byte_offset_to_start_of_line: 81023 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 29 columns.;
# line_number: 131 byte_offset_to_start_of_line: 124553 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 29 columns.;
# line_number: 227 byte_offset_to_start_of_line: 225954 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 29 columns.;
# line_number: 281 byte_offset_to_start_of_line: 287521 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 29 columns.;
# line_number: 304 byte_offset_to_start_of_line: 307207 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 29 columns.;
# line_number: 318 byte_offset_to_start_of_line: 318486 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 55 columns.;
# line_number: 25 byte_offset_to_start_of_line: 29065 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 55 columns.;
# line_number: 101 byte_offset_to_start_of_line: 94938 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 55 columns.;
# line_number: 110 byte_offset_to_start_of_line: 101916 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 55 columns.;
# line_number: 133 byte_offset_to_start_of_line: 125910 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 55 columns.;
# line_number: 154 byte_offset_to_start_of_line: 150268 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 55 columns.;
# line_number: 330 byte_offset_to_start_of_line: 333031 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 4 columns.; line_number:
# 26 byte_offset_to_start_of_line: 29933 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 11 columns.;
# line_number: 38 byte_offset_to_start_of_line: 41324 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 11 columns.;
# line_number: 53 byte_offset_to_start_of_line: 53330 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 11 columns.;
# line_number: 62 byte_offset_to_start_of_line: 60589 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 11 columns.;
# line_number: 79 byte_offset_to_start_of_line: 73099 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 11 columns.;
# line_number: 167 byte_offset_to_start_of_line: 163327 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 11 columns.;
# line_number: 252 byte_offset_to_start_of_line: 255053 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 11 columns.;
# line_number: 282 byte_offset_to_start_of_line: 287861 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 11 columns.;
# line_number: 348 byte_offset_to_start_of_line: 352012 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 39 byte_offset_to_start_of_line: 41548 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 40 byte_offset_to_start_of_line: 41549 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 41 byte_offset_to_start_of_line: 41550 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 42 byte_offset_to_start_of_line: 41551 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 54 byte_offset_to_start_of_line: 53580 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 63 byte_offset_to_start_of_line: 60804 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 64 byte_offset_to_start_of_line: 60868 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 72 byte_offset_to_start_of_line: 66708 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 88 byte_offset_to_start_of_line: 80984 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 102 byte_offset_to_start_of_line: 95727 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 111 byte_offset_to_start_of_line: 102778 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 130 byte_offset_to_start_of_line: 124533 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 134 byte_offset_to_start_of_line: 126811 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 155 byte_offset_to_start_of_line: 151176 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 221 byte_offset_to_start_of_line: 219481 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 279 byte_offset_to_start_of_line: 287402 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 280 byte_offset_to_start_of_line: 287466 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 302 byte_offset_to_start_of_line: 307145 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 303 byte_offset_to_start_of_line: 307206 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 314 byte_offset_to_start_of_line: 318352 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 315 byte_offset_to_start_of_line: 318394 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 316 byte_offset_to_start_of_line: 318439 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 317 byte_offset_to_start_of_line: 318485 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 334 byte_offset_to_start_of_line: 335620 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 350 byte_offset_to_start_of_line: 352361 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 1 columns.; line_number:
# 363 byte_offset_to_start_of_line: 365728 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 26 columns.;
# line_number: 43 byte_offset_to_start_of_line: 41552 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 26 columns.;
# line_number: 56 byte_offset_to_start_of_line: 54127 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 26 columns.;
# line_number: 65 byte_offset_to_start_of_line: 61320 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 26 columns.;
# line_number: 81 byte_offset_to_start_of_line: 73892 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 26 columns.;
# line_number: 103 byte_offset_to_start_of_line: 95761 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 26 columns.;
# line_number: 169 byte_offset_to_start_of_line: 164386 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 26 columns.;
# line_number: 174 byte_offset_to_start_of_line: 167913 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 26 columns.;
# line_number: 179 byte_offset_to_start_of_line: 172602 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 26 columns.;
# line_number: 183 byte_offset_to_start_of_line: 174770 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 26 columns.;
# line_number: 351 byte_offset_to_start_of_line: 352803 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 26 columns.;
# line_number: 361 byte_offset_to_start_of_line: 363481 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 39 columns.;
# line_number: 55 byte_offset_to_start_of_line: 53659 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 39 columns.;
# line_number: 168 byte_offset_to_start_of_line: 163560 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 2 columns.; line_number:
# 70 byte_offset_to_start_of_line: 66591 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 2 columns.; line_number:
# 285 byte_offset_to_start_of_line: 290720 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 2 columns.; line_number:
# 286 byte_offset_to_start_of_line: 290863 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 2 columns.; line_number:
# 287 byte_offset_to_start_of_line: 291013 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 2 columns.; line_number:
# 349 byte_offset_to_start_of_line: 352233 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 3 columns.; line_number:
# 71 byte_offset_to_start_of_line: 66643 column_index: 85
# column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 25 columns.;
# line_number: 73 byte_offset_to_start_of_line: 66724 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 24 columns.;
# line_number: 80 byte_offset_to_start_of_line: 73320 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 15 columns.;
# line_number: 105 byte_offset_to_start_of_line: 97081 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 15 columns.;
# line_number: 172 byte_offset_to_start_of_line: 167065 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 15 columns.;
# line_number: 181 byte_offset_to_start_of_line: 173849 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 15 columns.;
# line_number: 333 byte_offset_to_start_of_line: 335346 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 15 columns.;
# line_number: 360 byte_offset_to_start_of_line: 363028 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 70 columns.;
# line_number: 106 byte_offset_to_start_of_line: 97382 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 70 columns.;
# line_number: 283 byte_offset_to_start_of_line: 288066 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 32 columns.;
# line_number: 112 byte_offset_to_start_of_line: 102779 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 32 columns.;
# line_number: 135 byte_offset_to_start_of_line: 126812 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 32 columns.;
# line_number: 156 byte_offset_to_start_of_line: 151177 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 32 columns.;
# line_number: 331 byte_offset_to_start_of_line: 333751 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 42 columns.;
# line_number: 173 byte_offset_to_start_of_line: 167364 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 42 columns.;
# line_number: 182 byte_offset_to_start_of_line: 174158 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 51 columns.;
# line_number: 220 byte_offset_to_start_of_line: 218646 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 74 columns.;
# line_number: 253 byte_offset_to_start_of_line: 255267 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 33 columns.;
# line_number: 288 byte_offset_to_start_of_line: 291359 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# - Error while reading data, error message: CSV table references
# column position 85, but line contains only 30 columns.;
# line_number: 335 byte_offset_to_start_of_line: 336263 column_index:
# 85 column_name: "YOBClosed" column_type: STRING
# BigQuery error in show operation: Not found: Table jas-
# test:vanai_hackathons.music_survey_data

# %% [markdown]
# * CSV validator script needed

# %%
import csv

def validate_csv(file_path, delimiter=',', max_errors=20):
    errors = 0

    with open(file_path, 'r', newline='', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter=delimiter)
        
        try:
            header = next(reader)
        except Exception as e:
            print(f"Error reading header: {e}")
            return
        
        expected_columns = len(header)
        print(f"Header columns: {expected_columns}")

        for line_num, row in enumerate(reader, start=2):
            # Check column count
            if len(row) != expected_columns:
                print(f"Error line {line_num}: Expected {expected_columns} columns, found {len(row)} columns.")
                errors += 1
            
            # Optional: check for unclosed quotes by attempting to join and parse the line again
            # This is tricky here, usually csv.reader handles quoting, so focus on column count primarily

            if errors >= max_errors:
                print(f"Max error count {max_errors} reached. Stopping validation.")
                break

    if errors == 0:
        print("CSV validation passed - all rows have consistent column counts.")
    else:
        print(f"CSV validation ended with {errors} errors detected.")

# Usage example:
csv_file = INPUT_CSV_FILE_PATH  # change to your CSV file path
validate_csv(csv_file)
# Out:
# Header columns: 86
# CSV validation passed - all rows have consistent column counts.

# %%
# --allow_quoted_newlines=true to allow newlines within quoted strings.
# --field_delimiter=',' explicitly set delimiter.

# %%
# !bq load --source_format=CSV \
    --skip_leading_rows=1 \
    --schema=$OUTPUT_JSON_SCHEMA_FILE_PATH \
    --field_delimiter=',' \
    --allow_quoted_newlines=true \
    $PROJECT_ID:$DATASET_NAME"."$TABLE_NAME \
    $INPUT_CSV_FILE_PATH

# !bq show $PROJECT_ID:$DATASET_NAME"."$TABLE_NAME
# Out:
# Upload complete.
# Waiting on bqjob_r15c3c3bdec5481df_000001997a493f3e_1 ... (1s) Current status: DONE
# Table jas-test:vanai_hackathons.music_survey_data
#
#    Last modified                                 Schema                                 Total Rows   Total Bytes   Expiration   Time Partitioning   Clustered Fields   Total Logical Bytes   Total Physical Bytes   Labels
#  ----------------- ------------------------------------------------------------------- ------------ ------------- ------------ ------------------- ------------------ --------------------- ---------------------- --------
#   23 Sep 22:54:08   |- participant_id: string                                           1006         1252577                                                           1252577
#                     |- distribution_type: string
#                     |- distribution_name: string
#                     |- engagement_id: string
#                     |- engagement_started_EDT: string
#                     |- engagement_completed_EDT: string
#                     |- engagement_participation_status: string
#                     |- BrokerPanelId: string
#                     |- Q1_Relationship_with_music: string
#                     |- Q2_Discovering_music: string
#                     |- Q3_artist_that_pulled_you_in: string
#                     |- Q3_artist_that_pulled_you_in_sentiment: string
#                     |- Q3_artist_that_pulled_you_in_sentiment_percentage: string
#                     |- Q4_Music_format_changes: string
#                     |- Q5_Music_formal_change_impact: string
#                     |- Q5_Music_formal_change_impact_sentiment: string
#                     |- Q5_Music_formal_change_impact_sentiment_percentage: string
#                     |- Q6_Music_format_change_feelings: string
#                     |- Q7_New_music_discover_1: string
#                     |- Q7_New_music_discover_2: string
#                     |- Q7_New_music_discover_3: string
#                     |- Q7_New_music_discover_4: string
#                     |- Q7_New_music_discover_5: string
#                     |- Q7_New_music_discover_6: string
#                     |- Q7_New_music_discover_7: string
#                     |- Q8_Music_listen_time_GRID_1: string
#                     |- Q8_Music_listen_time_GRID_2: string
#                     |- Q8_Music_listen_time_GRID_3: string
#                     |- Q8_Music_listen_time_GRID_4: string
#                     |- Q8_Music_listen_time_GRID_5: string
#                     |- Q8_Music_listen_time_GRID_6: string
#                     |- Q9_Music_preference_these_days: string
#                     |- Q10_Songs_by_AI: string
#                     |- Q11_Use_of_dead_artists_voice_feelings: string
#                     |- Q12_Music_bingo_1: string
#                     |- Q12_Music_bingo_2: string
#                     |- Q12_Music_bingo_3: string
#                     |- Q12_Music_bingo_4: string
#                     |- Q12_Music_bingo_5: string
#                     |- Q12_Music_bingo_6: string
#                     |- Q12_Music_bingo_7: string
#                     |- Q13_Share_the_music_you_love_1: string
#                     |- Q13_Share_the_music_you_love_2: string
#                     |- Q13_Share_the_music_you_love_3: string
#                     |- Q13_Share_the_music_you_love_4: string
#                     |- Q13_Share_the_music_you_love_5: string
#                     |- Q13_Share_the_music_you_love_6: string
#                     |- Q14_Friend_shares_a_song: string
#                     |- Q15_Music_guilty_pleasure: string
#                     |- Q16_Music_guilty_pleasure_Video_or_text: string
#                     |- Q16_Music_guilty_pleasure_text_OE: string
#                     |- Q16_Music_guilty_pleasure_text_OE_sentiment: string
#                     |- Q16_Music_guilty_pleasure_text_OE_sentiment_percentage: string
#                     |- Q17_Video_share_concent: string
#                     |- Q18_Life_theme_song: string
#                     |- Q18_Life_theme_song_sentiment: string
#                     |- Q18_Life_theme_song_sentiment_percentage: string
#                     |- Q19_Lyric_that_stuck_with_you: string
#                     |- Q19_Lyric_that_stuck_with_you_sentiment: string
#                     |- Q19_Lyric_that_stuck_with_you_sentiment_percentage: string
#                     |- Gender: string
#                     |- Education: string
#                     |- HH_Income_Fine_23: string
#                     |- Ethnicity_Roll_23: string
#                     |- Vizmin_23: string
#                     |- HH_Comp_23: string
#                     |- KidsinHH_23_Expecting_a_baby: string
#                     |- KidsinHH_23_2: string
#                     |- KidsinHH_23_3: string
#                     |- KidsinHH_23_4: string
#                     |- KidsinHH_23_5: string
#                     |- KidsinHH_23_6: string
#                     |- KidsinHH_23_7: string
#                     |- KidsinHH_23_8: string
#                     |- KidsinHH_23_9: string
#                     |- HH_Under18_23: string
#                     |- CMA: string
#                     |- Province: string
#                     |- Age: string
#                     |- Region: string
#                     |- FirstNation_23_1: string
#                     |- FirstNation_23_2: string
#                     |- FirstNation_23_3: string
#                     |- FirstNation_23_4: string
#                     |- AgeGroup_Broad: string
#                     |- YOBClosed: string
